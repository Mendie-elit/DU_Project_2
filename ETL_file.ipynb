# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL
import requests

# %% [markdown]
# ### Extract CSV file into Dataframe

# %%
# Relationship Data file

relationship_data = "../Project-2/relationship_data_file.csv"
relationship_data_df = pd.read_csv(relationship_data)
relationship_data_df.head(15)
# relationship_data_df.count()
# relationship_data_df.dtypes
# Out:
# C:\Users\mendi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (48,103) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Unnamed: 0  CaseID  CASEID_NEW          qflag  weight1  weight1_freqwt  \
# 0            0       2     2014039      Qualified      NaN             NaN
# 1            1       3     2019003      Qualified   0.9078         71115.0
# 2            2       5     2145527      Qualified   0.7205         56442.0
# 3            3       6     2648857      Qualified   1.2597         98682.0
# 4            4       7     2623465      Qualified   0.8686         68044.0
# 5            5       9     2917189      Qualified   0.8815         69054.0
# 6            6      10     2919423      Qualified   0.8381         65655.0
# 7            7      11     2936569      Qualified   0.7752         60727.0
# 8            8      12     1840651  Not Qualified      NaN             NaN
# 9            9      13     1840371      Qualified   1.0973         85960.0
# 10          10      14     2089701      Qualified   0.8716         68279.0
# 11          11      15     1939669      Qualified   1.2145         95141.0
# 12          12      16      645963      Qualified   0.9694         75940.0
# 13          13      17      729415      Qualified   1.2698         99473.0
# 14          14      18     2710813      Qualified   0.9109         71358.0
#
#     weight2  weight1a  weight1a_freqwt  weight_combo      ...       \
# 0    0.8945       NaN              NaN      0.277188      ...
# 1       NaN    0.9026          70707.0      1.020621      ...
# 2       NaN    0.7164          56121.0      0.810074      ...
# 3    1.3507    1.2524          98110.0      0.418556      ...
# 4       NaN    0.8636          67652.0      0.976522      ...
# 5    1.8263    0.8765          68663.0      0.565935      ...
# 6       NaN    0.8333          65279.0      0.942260      ...
# 7       NaN    0.7708          60383.0      0.871587      ...
# 8       NaN    0.9731          76230.0      1.100340      ...
# 9       NaN    1.0910          85466.0      1.233656      ...
# 10      NaN    0.8666          67887.0      0.979914      ...
# 11      NaN    1.2075          94593.0      1.365389      ...
# 12      NaN    0.9638          75502.0      1.089824      ...
# 13      NaN    1.2625          98901.0      1.427581      ...
# 14      NaN    0.9057          70950.0      1.024127      ...
#
#     hcm2017q24_met_through_family  hcm2017q24_met_through_friend  \
# 0                              no                             no
# 1                              no                             no
# 2                              no                             no
# 3                              no                             no
# 4                              no                             no
# 5                              no                             no
# 6                              no                            yes
# 7                              no                             no
# 8                             NaN                            NaN
# 9                             yes                             no
# 10                             no                             no
# 11                            NaN                            NaN
# 12                             no                             no
# 13                             no                             no
# 14                            yes                            yes
#
#    hcm2017q24_met_through_as_nghbrs hcm2017q24_met_as_through_cowork  \
# 0                                no                               no
# 1                                no                              yes
# 2                                no                               no
# 3                                no                               no
# 4                               yes                               no
# 5                                no                               no
# 6                                no                               no
# 7                                no                               no
# 8                               NaN                              NaN
# 9                                no                               no
# 10                               no                              yes
# 11                              NaN                              NaN
# 12                               no                               no
# 13                               no                               no
# 14                               no                               no
#
#            w6_subject_race interracial_5cat partner_mother_yrsed  \
# 0                    White               no                 12.0
# 1                    White               no                 12.0
# 2                    White               no                  9.0
# 3                    White               no                 16.0
# 4                    White               no                 14.0
# 5                    White               no                 12.0
# 6                    White               no                 12.0
# 7                    White               no                 12.0
# 8                    White              NaN                  NaN
# 9   Other (please specify)               no                  0.0
# 10                   White               no                 12.0
# 11                   White               no                 13.0
# 12                   White               no                 13.0
# 13                   White               no                  NaN
# 14                   White              yes                 16.0
#
#    subject_mother_yrsed  partner_yrsed subject_yrsed
# 0                  14.0           12.0          14.0
# 1                  16.0           17.0          17.0
# 2                   7.5           14.0          17.0
# 3                  12.0           12.0          12.0
# 4                  17.0           16.0          16.0
# 5                  12.0           16.0          12.0
# 6                   7.5           13.0          12.0
# 7                  12.0           20.0          14.0
# 8                   NaN            NaN          16.0
# 9                   5.5           12.0          12.0
# 10                 16.0           16.0          16.0
# 11                 12.0           14.0          14.0
# 12                 17.0           16.0          16.0
# 13                 12.0           13.0          12.0
# 14                 16.0           17.0          20.0
#
# [15 rows x 286 columns]

# %% [markdown]
# ### Transform Dataframes

# %%
# Create a filtered dataframe from specific columns for relationship data, noted data from different versions of surveys.
# Based on analysis of data it appears data with column prefix w6_ is most relevant

relationship_data_cols = ["CASEID_NEW", 
                          "w6_q21a_year", 
                          "w6_relationship_end_nonmar", 
                          "w6_breakup_nonmar", 
                          "w6_relationship_end_mar", 
                          "w6_who_breakup",
                          "ppagecat",
                          "ppagect4",
                          "ppmarit",
                          "w6_q19",
                          "w6_q20",
                          "w6_q21a_month",
                          "w6_q21b_month",
                          "w6_q21c_month",
                          "w6_q21d_month", 
                          "w6_q21e_month",
                          "w6_q21f_month",
                          "partnership_status",
                          "w6_relationship_quality",
                          "ppage",
                          "w6_q9",
                          "w6_q17",
                          "w6_q21b_year",
                          "w6_q21c_year",
                          "w6_q21d_year",
                          "w6_q21e_year",
                          "w6_q21f_year",
                          "year_fraction_met",
                          "year_fraction_relstart",
                          "age_when_met",
                          "time_from_met_to_rel",
                          "year_fraction_first_cohab",
                          "time_from_rel_to_cohab"]                        
relat_data_transformed = relationship_data_df[relationship_data_cols].copy()



# Clean the data by dropping duplicates and setting the index
# premise_transformed.drop_duplicates("id", inplace=True)
relat_data_transformed.set_index("CASEID_NEW", inplace=True)

relat_data_transformed.head()
# Out:
#             w6_q21a_year w6_relationship_end_nonmar  \
# CASEID_NEW
# 2014039           2017.0                We broke up
# 2019003           1983.0                        NaN
# 2145527           2006.0                        NaN
# 2648857           2012.0                We broke up
# 2623465           1983.0                        NaN
#
#                                  w6_breakup_nonmar w6_relationship_end_mar  \
# CASEID_NEW
# 2014039                  I wanted to break up more                     NaN
# 2019003                                        NaN                     NaN
# 2145527                                        NaN                     NaN
# 2648857     [Partner Name] wanted to break up more                     NaN
# 2623465                                        NaN                     NaN
#
#            w6_who_breakup ppagecat ppagect4        ppmarit w6_q19 w6_q20  \
# CASEID_NEW
# 2014039               NaN    25-34    30-44       Divorced    NaN     No
# 2019003               NaN    55-64    45-59        Married    Yes    NaN
# 2145527               NaN    45-54    45-59        Married    Yes    NaN
# 2648857               NaN    25-34    18-29  Never married    NaN     No
# 2623465               NaN    55-64    45-59        Married    Yes    NaN
#
#                      ...           w6_q21c_year w6_q21d_year w6_q21e_year  \
# CASEID_NEW           ...
# 2014039              ...                    NaN          NaN       2017.0
# 2019003              ...                 1996.0       1996.0          NaN
# 2145527              ...                 2006.0       2008.0          NaN
# 2648857              ...                    NaN          NaN       2013.0
# 2623465              ...                 1984.0       1984.0          NaN
#
#            w6_q21f_year year_fraction_met year_fraction_relstart age_when_met  \
# CASEID_NEW
# 2014039             NaN         2017.2084              2017.2084         30.0
# 2019003             NaN         1983.3750              1995.6250         21.0
# 2145527             NaN         2006.0416              2006.4584         36.0
# 2648857             NaN         2012.2084              2013.2916         23.0
# 2623465             NaN         1983.7084              1983.7916         25.0
#
#            time_from_met_to_rel  year_fraction_first_cohab  \
# CASEID_NEW
# 2014039                0.000000                        NaN
# 2019003               12.250000                  1996.1250
# 2145527                0.416748                  2006.5416
# 2648857                1.083252                        NaN
# 2623465                0.083252                  1984.6250
#
#             time_from_rel_to_cohab
# CASEID_NEW
# 2014039                        NaN
# 2019003                   0.500000
# 2145527                   0.083252
# 2648857                        NaN
# 2623465                   0.833374
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Analytics

# %% [markdown]
# ## Create database connection

# %%
# Need to add password to access the database


db_url = {
   'database': 'relationship_data_db',
   'drivername': 'mysql',
   'username': 'root',
   'password': '1Lovemykid$',
   'host': '127.0.0.1',
   'query': {'charset': 'utf8'},  # the key-point setting
}

engine = create_engine(URL(**db_url), encoding='utf8')

# %%
relat_data_transformed.to_sql(name='relationship_data', con=engine, if_exists='append', index=True)
